# %%
import requests
from bs4 import BeautifulSoup
import time
import random

user_agents = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1 Safari/605.1.15',
    'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
]


BASE_URL = "https://www3.animeflv.net/browse?page="  
ANIME_URL = "https://www3.animeflv.net"

page = 1
failures = 0 
links = []

while True:

    url = BASE_URL + str(page)
    headers = {'User-Agent': random.choice(user_agents)}

    try:

        r = requests.get(url, headers=headers)
        soup = BeautifulSoup(r.content, 'lxml')
        anime_links = soup.find_all('article', class_='Anime alt B') 

        if len(anime_links) == 0:
                failures += 1
        else:
            failures = 0    
            for anime in anime_links:
                link = anime.find('a')['href']
                links.append(ANIME_URL + link)

        page += 1


    except Exception:
        failures += 1

    if failures >= 2:
        break

    time.sleep(random.randint(5, 10 ))

#remove duplicates
links = list(set(links))
    
with open('anime_links.txt', 'a') as f:
    for link in links:
        f.write(link + "\n")

print(f"Scraped {page - 1} pages")
# Out:
# Scraped 9 pages

# %%
import pandas as pd 
import re 
import requests
from bs4 import BeautifulSoup
import time
import random

# %%
#Only if you start from the list 

user_agents = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1 Safari/605.1.15',
    'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
]


#Second part scrap the data from the links

data = []
check_point = 50 #checkpoint to save the data
links_processed = 0

# If resuming, load previously saved data and update links_processed

try:
    existing_data = pd.read_csv('anime_data.csv')
    data = existing_data.to_dict(orient='records')
    print(f'Resuming from link {len(data)}.')
except (FileNotFoundError, pd.errors.EmptyDataError):
    print('Starting from scratch.')

#Read the links from the file
with open('anime_links.txt', 'r') as f:
    links = f.read().splitlines()

# If we're resuming, skip the already processed links
if 'existing_data' in locals():
    links = links[len(data):]

for link in links: 

    try:

        url = link

        headers = {'User-Agent': random.choice(user_agents)}
        r = requests.get(url, headers=headers)
        soup = BeautifulSoup(r.content, 'lxml')

        # Code for year and episode number

        scripts = soup.find_all('script')

        # Initialize variables to store the information we are looking for
        last_episode_number = None
        last_episode_year = None

        # Now let's loop through all <script> elements and apply our regular expressions
        for script in scripts:
            if script.string:
                # Find the episodes array using a regular expression
                episodes_search = re.search(r'var episodes = \[\[(\d+),\d+\]', script.string)
                if episodes_search:
                    last_episode_number = episodes_search.group(1)

        #Varibles init here for titles 
        alt_title_1_text = None
        alt_title_2_text = None

        
        title = soup.find('h1', class_='Title').text
        span = soup.find('h1').find_next_sibling('span')
        tv_type = span.text

        alt_title_1 = soup.find('span', class_='TxtAlt')
        if alt_title_1:
            alt_title_1_text = alt_title_1.text.strip()
            alt_title_2 = alt_title_1.find_next_sibling('span', class_='TxtAlt')
            if alt_title_2:
                alt_title_2_text = alt_title_2.text.strip()
        else:
            alt_title_1 = None
            alt_title_2 = None
        rating = soup.find('span', class_='vtprmd')
        if rating:
            rating = rating.text
        else:
            rating = None
        description = soup.find('div', class_='Description').text
        description = description.replace('\n', '')
        genres = [a.text for a in soup.find('nav', class_='Nvgnrs').find_all('a')]
        followers = soup.find('div', class_='Top').find('div', class_='Title').text
        followers  = followers.replace('Seguidores: ', '')
        status = soup.find('span', class_='fa-tv').text
        

        data.append({
            'url': url,
            'title': title,
            'type_tv': tv_type,
            'alt_title_1': alt_title_1_text,
            'alt_title_2': alt_title_2_text,
            'rating': rating,
            'description': description,
            'genres': genres,
            'followers': followers,
            'status': status,
            'last_episode_number': last_episode_number
        })

    except Exception as e:
        print(f'Failed to process {link}: {type(e).__name__}, {e}')

    links_processed += 1

    if links_processed % check_point == 0:
        pd.DataFrame(data).to_csv('anime_data.csv', index=False)
        print(f'Saved checkpoint at link {links_processed}.')

    time.sleep(random.randint(1, 5))

# Save the remaining data if it's not an exact multiple of our checkpoint interval
if links_processed % check_point != 0:
    pd.DataFrame(data).to_csv('anime_data.csv', index=False)

print(f'Scraping complete. Processed {links_processed} links in total.')
# Out:
# Resuming from link 49.
# Failed to process https://www3.animeflv.net/anime/kimi-no-iru-machi-uchi-ga-kita-machi: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/hokuto-no-ken-raoh-gaiden-junai-hen: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/yuyushiki: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 50.
# Saved checkpoint at link 100.
# Failed to process https://www3.animeflv.net/anime/hikaru-no-go: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 150.
# Failed to process https://www3.animeflv.net/anime/special-a: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/mnemosyne: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 200.
# Failed to process https://www3.animeflv.net/anime/yami-shibai-6: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/haiyoru-nyaruko-san: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 250.
# Saved checkpoint at link 300.
# Saved checkpoint at link 350.
# Saved checkpoint at link 400.
# Failed to process https://www3.animeflv.net/anime/yami-shibai-5th-season: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 450.
# Failed to process https://www3.animeflv.net/anime/la-storia-della-arcana-famiglia: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 500.
# Saved checkpoint at link 550.
# Saved checkpoint at link 600.
# Saved checkpoint at link 650.
# Saved checkpoint at link 700.
# Saved checkpoint at link 750.
# Saved checkpoint at link 800.
# Failed to process https://www3.animeflv.net/anime/needless: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 850.
# Saved checkpoint at link 900.
# Saved checkpoint at link 950.
# Saved checkpoint at link 1000.
# Failed to process https://www3.animeflv.net/anime/medaka-box: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/uta-no-prince-sama-maji-love-2000: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 1050.
# Saved checkpoint at link 1100.
# Failed to process https://www3.animeflv.net/anime/yami-shibai: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 1150.
# Saved checkpoint at link 1200.
# Failed to process https://www3.animeflv.net/anime/kimi-no-iru-machi-tasogare-kousaten: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/super-sonico-the-animation: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 1250.
# Failed to process https://www3.animeflv.net/anime/break-blade: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 1300.
# Saved checkpoint at link 1350.
# Failed to process https://www3.animeflv.net/anime/hyakka-ryouran-samurai-bride: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/break-blade-2014: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/towa-no-quon: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 1400.
# Saved checkpoint at link 1450.
# Failed to process https://www3.animeflv.net/anime/kami-nomi-zo-shiru-sekai: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 1500.
# Failed to process https://www3.animeflv.net/anime/yami-shibai-7: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 1550.
# Failed to process https://www3.animeflv.net/anime/hokuto-no-ken-raoh-gaiden-gekitou-hen: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/eiyuu-densetsu-sora-no-kiseki-the-animation: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 1600.
# Failed to process https://www3.animeflv.net/anime/uta-no-prince-sama-maji-love-1000: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 1650.
# Saved checkpoint at link 1700.
# Failed to process https://www3.animeflv.net/anime/shugo-chara: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 1750.
# Saved checkpoint at link 1800.
# Failed to process https://www3.animeflv.net/anime/haiyore-nyaruko-san-w: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 1850.
# Failed to process https://www3.animeflv.net/anime/kannazuki-no-miko: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 1900.
# Failed to process https://www3.animeflv.net/anime/seikon-no-qwaser-ii: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/cannan: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 1950.
# Failed to process https://www3.animeflv.net/anime/yami-shibai-3rd-season: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 2000.
# Saved checkpoint at link 2050.
# Failed to process https://www3.animeflv.net/anime/mazinkaiser-skl: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 2100.
# Failed to process https://www3.animeflv.net/anime/yami-shibai-8: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 2150.
# Saved checkpoint at link 2200.
# Saved checkpoint at link 2250.
# Saved checkpoint at link 2300.
# Failed to process https://www3.animeflv.net/anime/level-e: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 2350.
# Failed to process https://www3.animeflv.net/anime/hayate-no-gotoku: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/muv-luv-alternative-total-eclipse: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 2400.
# Saved checkpoint at link 2450.
# Saved checkpoint at link 2500.
# Failed to process https://www3.animeflv.net/anime/amnesia: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 2550.
# Saved checkpoint at link 2600.
# Saved checkpoint at link 2650.
# Saved checkpoint at link 2700.
# Failed to process https://www3.animeflv.net/anime/skip-beat: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 2750.
# Failed to process https://www3.animeflv.net/anime/tegami-bachi: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 2800.
# Failed to process https://www3.animeflv.net/anime/shinryaku-ika-musume: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 2850.
# Failed to process https://www3.animeflv.net/anime/kimi-no-iru-machi: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 2900.
# Failed to process https://www3.animeflv.net/anime/hyakka-ryoran: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 2950.
# Saved checkpoint at link 3000.
# Saved checkpoint at link 3050.
# Failed to process https://www3.animeflv.net/anime/sket-dance: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 3100.
# Failed to process https://www3.animeflv.net/anime/yami-shibai-2: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 3150.
# Saved checkpoint at link 3200.
# Failed to process https://www3.animeflv.net/anime/getter-robo-arc: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/aria-the-animation: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 3250.
# Saved checkpoint at link 3300.
# Failed to process https://www3.animeflv.net/anime/rail-romanesque: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/yami-shibai-4th-season: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/tari-tari: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 3350.
# Failed to process https://www3.animeflv.net/anime/hokuto-no-ken-raou-gaiden-ten-no-haou: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/tears-to-tiara: AttributeError, 'NoneType' object has no attribute 'text'
# Failed to process https://www3.animeflv.net/anime/cuticle-detective-inaba: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 3400.
# Saved checkpoint at link 3450.
# Failed to process https://www3.animeflv.net/anime/eyeshield-21: AttributeError, 'NoneType' object has no attribute 'text'
# Saved checkpoint at link 3500.
# Scraping complete. Processed 3542 links in total.
